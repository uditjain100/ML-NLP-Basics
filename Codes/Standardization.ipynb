# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('/content/Social_Network_Ads.csv')
df.head()
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510    Male   19            19000          0
# 1  15810944    Male   35            20000          0
# 2  15668575  Female   26            43000          0
# 3  15603246  Female   27            57000          0
# 4  15804002    Male   19            76000          0

# %%
df = df.iloc[:, 2:]
df.sample(5)
# Out:
#      Age  EstimatedSalary  Purchased
# 322   41            52000          0
# 196   30            79000          0
# 140   19            85000          0
# 252   48           134000          1
# 262   55           125000          1

# %%
from sklearn.model_selection import train_test_split

X = df.drop('Purchased', axis=1)
y = df['Purchased']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %%
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()

sc.fit(X_train)

X_train_scaled = sc.transform(X_train)
X_test_scaled = sc.transform(X_test)

# As sc.transform returns a nd array not a dataframe
X_train_scaled = pd.DataFrame(X_train_scaled, columns=X_train.columns)
X_test_scaled = pd.DataFrame(X_test_scaled, columns=X_test.columns)

sc.mean_
# Out:
# array([3.78642857e+01, 6.98071429e+04])

# %%
X_train.describe()
# Out:
#               Age  EstimatedSalary
# count  280.000000       280.000000
# mean    37.864286     69807.142857
# std     10.218201     34641.201654
# min     18.000000     15000.000000
# 25%     30.000000     43000.000000
# 50%     37.000000     70500.000000
# 75%     46.000000     88000.000000
# max     60.000000    150000.000000

# %%
X_train_scaled.describe()
# Out:
#                 Age  EstimatedSalary
# count  2.800000e+02     2.800000e+02
# mean   3.489272e-17     6.344132e-17
# std    1.001791e+00     1.001791e+00
# min   -1.947491e+00    -1.584970e+00
# 25%   -7.710131e-01    -7.752370e-01
# 50%   -8.473441e-02     2.003677e-02
# 75%    7.976239e-01     5.261201e-01
# max    2.170181e+00     2.319101e+00

# %%
sns.scatterplot(x='Age', y='EstimatedSalary', data=X_train)
# Out:
# <Axes: xlabel='Age', ylabel='EstimatedSalary'>

# %%
sns.scatterplot(x='Age', y='EstimatedSalary', data=X_train_scaled, c='red')
# Out:
# <Axes: xlabel='Age', ylabel='EstimatedSalary'>

# %%
sns.kdeplot(x='Age', data=X_train)
sns.kdeplot(x='EstimatedSalary', data=X_train)
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.kdeplot(x='Age', data=X_train_scaled)
sns.kdeplot(x='EstimatedSalary', data=X_train_scaled)
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.kdeplot(x='Age', data=X_train)
sns.kdeplot(x='Age', data=X_train_scaled)
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.kdeplot(x='EstimatedSalary', data=X_train)
sns.kdeplot(x='EstimatedSalary', data=X_train_scaled)
# Out:
# <Axes: xlabel='EstimatedSalary', ylabel='Density'>
